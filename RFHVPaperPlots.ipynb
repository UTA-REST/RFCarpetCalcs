pdfactor_10 = 750.*0.0127*2
pdfactor_15 = 750.*0.0127*3

# %%
press_ar_5mil_dc = np.array([1.50,1.50,1.50,1.00,1.00,1.00,0.90,0.90,0.90,0.81,0.81,0.81,0.69,0.69,0.69,0.60,0.60,0.60,0.50,0.50,0.50,0.41,0.41,0.41,0.30,0.30,0.30,0.19,0.19,0.19])
volt_ar_5mil_dc = np.array([380.,370.,370.,310.,315.,315.,300.,300.,300.,290.,290.,290.,270.,267.,268.,260.,257.,257.,245.,244.,242.,230.,227.,227.,215.,210.,210.,200.,198.,199.])

pd_5mil_dc = press_ar_5mil_dc[::3]*pdfactor_5
volt_5mil_dc = volt_ar_5mil_dc.reshape(int(len(volt_ar_5mil_dc)/3),3).mean(axis=1)
err_pd_5mil_dc = np.sqrt((press_ar_5mil_dc[::3]*pdfactor_5/10.)**2 + (pdfactor_5*0.01)**2)
err_volt_5mil_dc = volt_ar_5mil_dc.reshape(int(len(volt_ar_5mil_dc)/3),3).std(axis=1)

# %%
press_ar_5mil_dc_cu = np.array([5.02,5.02,5.02,4.51,4.51,4.51,4.00,4.00,4.00,3.50,3.50,3.30,2.99,2.99,2.99,2.50,2.50,2.50,2.00,2.00,2.00,1.50,1.50,1.50,1.00,1.00,1.00,0.90,0.90,0.90,0.80,0.80,0.80,0.69,0.69,0.69,0.60,0.60,0.60,0.50,0.50,0.50,0.40,0.40,0.40,0.27,0.27,0.27,0.20,0.20,0.20])
volt_ar_5mil_dc_cu = np.array([850.,830.,840.,800.,780.,778.,750.,725.,730.,680.,675.,675.,630.,620.,620.,575.,565.,563.,500.,500.,497.,425.,425.,424.,350.,345.,341.,330.,325.,325.,310.,310.,310.,300.,290.,290.,275.,274.,274.,260.,256.,257.,240.,242.,240.,220.,221.,221.,212.,211.,212.])

pd_5mil_dc_cu = press_ar_5mil_dc_cu[::3]*pdfactor_5
volt_5mil_dc_cu = volt_ar_5mil_dc_cu.reshape(int(len(volt_ar_5mil_dc_cu)/3),3).mean(axis=1)
err_pd_5mil_dc_cu = np.sqrt((press_ar_5mil_dc_cu[::3]*pdfactor_5/10.)**2 + (pdfactor_5*0.01)**2)
err_volt_5mil_dc_cu = volt_ar_5mil_dc_cu.reshape(int(len(volt_ar_5mil_dc_cu)/3),3).std(axis=1)

# %%
press_ar_5mil_dc_oa = np.array([5.03,5.03,5.03,4.52,4.52,4.52,4.01,4.01,4.01,3.52,3.52,3.52,3.00,3.00,3.00,2.46,2.46,2.46,1.99,1.99,1.99,1.51,1.51,1.51,1.00,1.00,1.00,0.90,0.90,0.90,0.80,0.80,0.80,0.69,0.69,0.69,0.59,0.59,0.59,0.49,0.49,0.49,0.38,0.38,0.38,0.29,0.29,0.29,0.18,0.18,0.18])
volt_ar_5mil_dc_oa = np.array([900.,850.,880.,850.,830.,825.,775.,775.,775.,740.,720.,720.,675.,660.,600.,600.,590.,585.,550.,520.,520.,475.,450.,450.,385.,370.,370.,360.,360.,365.,360.,345.,340.,330.,320.,320.,290.,285.,295.,270.,275.,275.,250.,250.,250.,230.,230.,230.,215.,212.,211.])

pd_5mil_dc_oa = press_ar_5mil_dc_oa[::3]*pdfactor_5
volt_5mil_dc_oa = volt_ar_5mil_dc_oa.reshape(int(len(volt_ar_5mil_dc_oa)/3),3).mean(axis=1)
err_pd_5mil_dc_oa = np.sqrt((press_ar_5mil_dc_oa[::3]*pdfactor_5/10.)**2 +(pdfactor_5*0.01)**2)
err_volt_5mil_dc_oa = volt_ar_5mil_dc_oa.reshape(int(len(volt_ar_5mil_dc_oa)/3),3).std(axis=1)

# %%
press_ar_10mil_dc = np.array([3.98,3.98,3.98,3.50,3.50,3.50,2.99,2.99,2.99,2.50,2.50,2.50,1.99,1.99,1.99,1.46,1.46,1.46,1.00,1.00,1.00,0.91,0.91,0.91,0.80,0.80,0.80,0.70,0.70,0.70,0.60,0.60,0.60,0.50,0.50,0.50,0.40,0.40,0.40,0.29,0.29,0.29,0.17,0.17,0.17,0.10,0.10,0.10,0.06,0.06,0.06,0.04,0.04,0.04])
volt_ar_10mil_dc = np.array([1100.,1000.,1000.,975.,950.,930.,850.,860.,860.,775.,785.,780.,700.,690.,685.,575.,570.,565.,450.,450.,450.,430.,425.,424.,400.,396.,396.,375.,370.,370.,345.,344.,344.,315.,316.,318.,290.,284.,283.,260.,256.,256.,220.,222.,223.,212.,214.,214.,222.,223.,222.,245.,247.,246.])

pd_10mil_dc = press_ar_10mil_dc[::3]*pdfactor_10
volt_10mil_dc = volt_ar_10mil_dc.reshape(int(len(volt_ar_10mil_dc)/3),3).mean(axis=1)
err_pd_10mil_dc = np.sqrt((press_ar_10mil_dc[::3]*pdfactor_10/10.)**2 + (pdfactor_10*0.01)**2)
err_volt_10mil_dc = volt_ar_10mil_dc.reshape(int(len(volt_ar_10mil_dc)/3),3).std(axis=1)

# %% [markdown]
# ### RF

# %%
# Difference between probes at app
yatapp = np.array([168.,169.])
yatapp_std = np.array([1.,1.1])
batapp = np.array([177.])
batapp_std = np.array([1.3])

probe_std = np.abs(yatapp.mean() - batapp.mean())/yatapp.mean()

# %%
# yellow at app vs purple at divided -- 5 mil!
vapp_pp_5_v7 = np.array([219.,260.,298.,327.,356.,381.])
vapp_pp_5_v7_std = np.array([2.,2.,3.,3.,2.,2.])
vdiv_pp_5_v7 = np.array([0.540,0.634,0.721,0.794,0.861,0.927])
vdiv_pp_5_v7_std = np.array([0.005,0.006,0.005,0.006,0.006,0.010])
fact_5_v7_wtstds = vapp_pp_5_v7/vdiv_pp_5_v7*np.sqrt((vdiv_pp_5_v7_std/vdiv_pp_5_v7)**2+(vapp_pp_5_v7_std/vapp_pp_5_v7)**2)
vfactor_5_v7 = (vapp_pp_5_v7/vdiv_pp_5_v7).mean()
vfactor_5_v7_std = np.sqrt(sum(fact_5_v7_wtstds**2) + (probe_std*vfactor_5_v7)**2)
print('vfactor_5_v7 = %s +/- %s'%(vfactor_5_v7,vfactor_5_v7_std))
# Out:
# vfactor_5_v7 = 410.87996110206905 +/- 23.873328478845306

# %%
# yellow at app vs purple at divided -- 10 mil!
vapp_pp_10_v4 = np.array([229,274,317,348,378])
vapp_pp_10_v4_std = np.array([1.,1.5,2.,1.,2.])
vdiv_pp_10_v4 = np.array([0.652,0.775,0.913,1.00,1.07])
vdiv_pp_10_v4_std = np.array([0.005,0.006,0.010,0.005,0.010])

fact_10_v4_wtstds = vapp_pp_10_v4/vdiv_pp_10_v4*np.sqrt((vdiv_pp_10_v4_std/vdiv_pp_10_v4)**2+(vapp_pp_10_v4_std/vapp_pp_10_v4)**2)
vfactor_10_v4 = (vapp_pp_10_v4/vdiv_pp_10_v4).mean()
vfactor_10_v4_std = np.sqrt(sum(fact_10_v4_wtstds**2) + (probe_std*vfactor_10_v4)**2)
print('vfactor_10_v4 = %s +/- %s'%(vfactor_10_v4,vfactor_10_v4_std))
# Out:
# vfactor_10_v4 = 350.65068377136004 +/- 19.27212702487165

# %%
# yellow at app vs purple at divided -- 15 mil! (again! 8/8)
vapp_pp_15_v6 = np.array([250.,299.,340.,376.,408.])
vapp_pp_15_v6_std = np.array([3.,2.,1.5,3.,3.])
vdiv_pp_15_v6 = np.array([0.725,0.860,0.975,1.07,1.16])
vdiv_pp_15_v6_std = np.array([0.008,0.012,0.013,0.012,0.010])

fact_15_v6_wtstds = vapp_pp_15_v6/vdiv_pp_15_v6*np.sqrt((vdiv_pp_15_v6_std/vdiv_pp_15_v6)**2+(vapp_pp_15_v6_std/vapp_pp_15_v6)**2)
vfactor_15_v6 = (vapp_pp_15_v6/vdiv_pp_15_v6).mean()
vfactor_15_v6_std = np.sqrt(sum(fact_15_v6_wtstds**2) + (probe_std*vfactor_15_v6)**2)
print('vfactor_15_v6 = %s +/- %s'%(vfactor_15_v6,vfactor_15_v6_std))
# Out:
# vfactor_15_v6 = 348.86919212388193 +/- 20.821117822444407

# %%
press_ar_5mil_v7 = np.array([5.88,5.88,5.88,5.49,5.49,5.49,5.02,5.02,5.02,4.52,4.52,4.52,4.01,4.01,4.01,3.52,3.52,3.52,3.02,3.02,3.02,2.50,2.50,2.50,2.00,2.00,2.00,1.50,1.50,1.50,0.99,0.99,0.99,0.83,0.83,0.83,0.73,0.73,0.73,0.63,0.63,0.63,0.52,0.52,0.52,0.42,0.42,0.42,0.31,0.31,0.31,0.20,0.20,0.20])
volt_ar_5mil_v7 = np.array([3.56,2.38,2.38,2.66,2.52,3.16,2.42,3.50,3.24,3.08,3.14,2.68,2.32,2.48,1.90,2.52,2.46,2.26,2.54,2.60,2.36,2.28,2.34,2.50,2.08,2.24,2.22,1.90,1.82,1.84,1.52,1.48,1.46,1.40,1.34,1.36,1.30,1.28,1.30,1.20,1.22,1.20,1.14,1.14,1.12,1.04,1.04,1.06,1.04,1.04,1.06,0.84,0.94,0.82])

# %%
press_ar_10mil_v4 = np.array([4.42,4.42,4.42,4.03,4.03,4.03,3.51,3.51,3.51,2.99,2.99,2.99,2.51,2.51,2.51,2.01,2.01,2.01,1.52,1.52,1.52,1.00,1.00,1.00,0.92,0.92,0.92,0.80,0.80,0.80,0.69,0.69,0.69,0.61,0.61,0.61,0.50,0.50,0.50,0.40,0.40,0.40,0.31,0.31,0.31,0.21,0.21,0.21,0.10,0.10,0.10])
volt_ar_10mil_v4 = np.array([4.56,4.24,4.80,5.04,5.08,4.64,4.72,4.68,3.36,4.28,3.76,4.20,3.76,3.84,3.84,3.40,3.36,3.36,2.60,2.00,2.28,2.24,2.32,2.16,2.24,2.24,2.32,2.08,1.88,1.92,1.96,2.0,1.92,1.88,1.88,1.76,1.72,1.76,1.64,1.60,1.60,1.60,1.32,1.32,1.32,1.20,1.12,1.12,0.96,0.92,0.96])

# %%
press_ar_15mil_v6 = np.array([4.03,4.03,4.03,3.53,3.53,3.53,3.06,3.06,3.06,2.50,2.50,2.50,2.01,2.01,2.01,1.51,1.51,1.51,1.02,1.02,1.02,0.89,0.89,0.89,0.81,0.81,0.81,0.69,0.69,0.69,0.60,0.60,0.60,0.50,0.50,0.50,0.40,0.40,0.40,0.30,0.30,0.30,0.20,0.20,0.20,0.12,0.12,0.12])
volt_ar_15mil_v6 = np.array([8.0,5.12,3.28,4.96,4.90,4.16,4.56,4.08,4.32,4.80,4.24,4.64,4.32,4.72,4.56,4.16,3.0,3.88,3.28,3.44,3.28,3.12,3.16,3.16,3.0,2.92,2.96,2.76,2.68,2.76,2.60,2.48,2.48,2.28,2.28,2.28,2.04,2.0,2.0,1.76,1.76,1.84,1.52,1.52,1.44,1.2,1.32,1.32])

# %%
press_ar_5mil_v7_short = press_ar_5mil_v7[6:]
press_ar_10mil_v4_short = press_ar_10mil_v4[3:]
press_ar_15mil_v6_short = press_ar_15mil_v6[9:]
volt_ar_5mil_v7_short = volt_ar_5mil_v7[6:]
volt_ar_10mil_v4_short = volt_ar_10mil_v4[3:]
volt_ar_15mil_v6_short = volt_ar_15mil_v6[9:]

# %%
pd_5mil_rf = press_ar_5mil_v7_short[::3]*pdfactor_5
volt_5mil_rf = volt_ar_5mil_v7_short.reshape(int(len(volt_ar_5mil_v7_short)/3),3).mean(axis=1)*vfactor_5_v7/2.
err_pd_5mil_rf = np.sqrt((press_ar_5mil_v7_short[::3]*pdfactor_5/10.)**2 + (pdfactor_5*0.01)**2)
err_volt_5mil_rf = np.sqrt((vfactor_5_v7_std*volt_ar_5mil_v7_short[::3]/2.)**2 + (vfactor_5_v7*volt_ar_5mil_v7_short.reshape(int(len(volt_ar_5mil_v7_short)/3),3).std(axis=1)/2.)**2)

# %%
pd_10mil_rf = press_ar_10mil_v4_short[::3]*pdfactor_10
volt_10mil_rf = volt_ar_10mil_v4_short.reshape(int(len(volt_ar_10mil_v4_short)/3),3).mean(axis=1)*vfactor_10_v4/2.
err_pd_10mil_rf = np.sqrt((press_ar_10mil_v4_short[::3]*pdfactor_10/10.)**2 + (pdfactor_10*0.01)**2)
err_volt_10mil_rf = np.sqrt((vfactor_10_v4_std*volt_ar_10mil_v4_short[::3]/2.)**2 + (vfactor_10_v4*volt_ar_10mil_v4_short.reshape(int(len(volt_ar_10mil_v4_short)/3),3).std(axis=1)/2.)**2)

# %%
pd_15mil_rf = press_ar_15mil_v6_short[::3]*pdfactor_15
volt_15mil_rf = volt_ar_15mil_v6_short.reshape(int(len(volt_ar_15mil_v6_short)/3),3).mean(axis=1)*vfactor_15_v6/2.
err_pd_15mil_rf = np.sqrt((press_ar_15mil_v6_short[::3]*pdfactor_15/10.)**2 + (pdfactor_15*0.01)**2)
err_volt_15mil_rf = np.sqrt((vfactor_15_v6_std*volt_ar_15mil_v6_short[::3]/2.)**2 + (vfactor_15_v6*volt_ar_15mil_v6_short.reshape(int(len(volt_ar_15mil_v6_short)/3),3).std(axis=1)/2.)**2)

# %% [markdown]
# ## Plot breakdown curves

# %%
plt.figure(figsize=(9,7))

plt.plot(pd_raju,volt_raju,'^',label='Raju',c='C1')
plt.plot(pd_petrovic,volt_petrovic,'^',label='Petrovic',c='C3')
plt.plot(pd_farag,volt_farag_cu,'o',label='Farag - Cu, S=19.62cm',c=cmocean.cm.speed(5./5.))
plt.plot(pd_farag,volt_farag_ss,'o',label='Farag - SS, S=19.62cm',c=cmocean.cm.speed(3./5.))
plt.plot(pd_farag,volt_farag_al,'o',label='Farag - Al, S=19.62cm',c=cmocean.cm.speed(1./5.))
plt.plot(pd_farag_s,volt_farag_3846,'o',label='Farag - Al, S=38.46cm',c=cmocean.cm.matter(3./5.))
plt.plot(pd_lisovskiy_05,volt_lisovskiy_05,'D',label='Lisovskiy - 0.5 cm',c='C3')
plt.plot(pd_lisovskiy_10,volt_lisovskiy_10,'D',label='Lisovskiy - 1.0 cm',c='C4')
plt.plot(pd_lisovskiy_20,volt_lisovskiy_20,'D',label='Lisovskiy - 2.0 cm',c='C5')
plt.plot(pd_lisovskiy_40,volt_lisovskiy_40,'D',label='Lisovskiy - 4.0 cm',c='C6')
plt.plot(pd_lisovskiy_60,volt_lisovskiy_60,'D',label='Lisovskiy - 6.0 cm',c='peru')
plt.plot(pd_wittenberg,volt_wittenberg,label='Wittenberg',c='C1',alpha=0.6)
plt.plot(paschen(11.5,176,0.01,np.logspace(-1,3,1000))[0],paschen(11.5,176,0.01,np.logspace(-1,3,1000))[1],label='Petrovic',c='C3',alpha=0.6)

#plt.errorbar(pd_5mil_dc_oa,volt_5mil_dc_oa,xerr=err_pd_5mil_dc_oa,yerr=err_volt_5mil_dc_oa,fmt='.',label='5 mil - Cu - SA=1/3',c='midnightblue')
plt.errorbar(pd_5mil_dc_cu,volt_5mil_dc_cu,xerr=err_pd_5mil_dc_cu,yerr=err_volt_5mil_dc_cu,fmt='.',label='0.013 cm - C\n (this work)',c='midnightblue')
plt.errorbar(pd_5mil_dc,volt_5mil_dc,xerr=err_pd_5mil_dc,yerr=err_volt_5mil_dc,fmt='.',label='0.013 cm - Al\n (this work)',c='slateblue')
plt.errorbar(pd_10mil_dc[:-3],volt_10mil_dc[:-3],xerr=err_pd_10mil_dc[:-3],yerr=err_volt_10mil_dc[:-3],fmt='.',label='0.026 cm - Al\n (this work)',c='C9')

plt.xlim(0.8,87)
plt.ylim(100,3500)

plt.xscale('log')
plt.yscale('log')

line4 = plt.Line2D(range(10), range(10), marker='', color="white")
line5 = plt.Line2D(range(10), range(10), marker='', color="white")
line6 = plt.Line2D(range(10), range(10), marker='', color="white")
line7 = plt.Line2D(range(10), range(10), marker='', color="white")
line8 = plt.Line2D(range(10), range(10), marker='', color="white")
line9 = plt.Line2D(range(10), range(10), marker='', color="white")
line10 = plt.Line2D(range(10), range(10), marker='', color="white")
line11 = plt.Line2D(range(10), range(10), marker='', color="white")
(lines, labels) = plt.gca().get_legend_handles_labels()
lines.insert(16,line4)
labels.insert(16,'')
lines.insert(17,line5)
labels.insert(17,'')
lines.insert(18,line6)
labels.insert(18,'')
lines.insert(19,line7)
labels.insert(19,'')
lines.insert(20,line8)
labels.insert(20,'')
lines.insert(21,line9)
labels.insert(21,'')
#lines.insert(22,line10)
#labels.insert(22,'')
#lines.insert(23,line11)
#labels.insert(23,'')
#lines.insert(24,line11)
#labels.insert(24,'')

plt.legend(lines,labels,loc='upper left',ncol=2,fontsize=14)

plt.tick_params(which='major',axis='both',labelsize=20)
plt.xlabel('Pd [Torr cm]', fontsize=20)
plt.ylabel('DC Voltage [V]',fontsize=20)

plt.text(35,120,'Argon',fontsize=24)

plt.tight_layout()
#plt.savefig('plots/argoncomparedc_si.pdf',bbox_inches='tight')

# %%
plt.figure(figsize=(9,7))

plt.plot(pd_lisovskiy_65mm,volt_lisovskiy_65mm,'^',label='Lisovskiy - 0.65 cm',c='darkgreen')
plt.plot(pd_lisovskiy_13mm,volt_lisovskiy_13mm,'^',label='Lisovskiy - 1.3 cm',c='C2')
plt.plot(pd_lisovskiy_23mm,volt_lisovskiy_23mm,'^',label='Lisovskiy - 2.3 cm',c='lime')
plt.plot(pd_smith_2cm,volt_smith_2cm,'o',label='Smith - 2 cm',c='darkred')
plt.plot(pd_smith_5cm,volt_smith_5cm,'o',label='Smith - 5 cm',c='C3')
plt.plot(pd_smith_10cm,volt_smith_10cm,'o',label='Smith - 10 cm',c='salmon')
plt.plot(pd_sato_2cm,volt_sato_2cm,'D',label='Sato - 2 cm',c='k')
plt.plot(pd_sato_4cm,volt_sato_4cm,'D',label='Sato - 4 cm',c='gray')
plt.plot(pd_sato_6cm,volt_sato_6cm,'D',label='Sato - 6 cm',c='lightgray')

plt.errorbar(pd_5mil_rf, volt_5mil_rf, xerr=err_pd_5mil_rf, yerr=err_volt_5mil_rf,fmt='.', label='0.013 cm (this work)',c='darkblue')
plt.errorbar(pd_10mil_rf, volt_10mil_rf, xerr=err_pd_10mil_rf, yerr=err_volt_10mil_rf,fmt='.', label='0.026 cm (this work)',c='C0')
plt.errorbar(pd_15mil_rf, volt_15mil_rf, xerr=err_pd_15mil_rf, yerr=err_volt_15mil_rf,fmt='.', label='0.038 cm (this work)',c='C9')

plt.xlim(1,120)
#plt.ylim(50,2600)

plt.xscale('log')
#plt.yscale('log')

plt.legend(loc='upper left',ncol=2, fontsize=14)

plt.tick_params(which='major',axis='both',labelsize=20)
plt.xlabel('Pd [Torr cm]', fontsize=20)
plt.ylabel('RF Voltage [V]',fontsize=20)

plt.text(40,60,'Argon',fontsize=24)

plt.tight_layout()
#plt.savefig('plots/argoncomparerf_si.pdf',bbox_inches='tight')

# %%
fig,axs = plt.subplots(2,2,sharex=True,sharey=True,gridspec_kw={'hspace': 0,'wspace': 0},figsize=(10,6))

axs[0,1].errorbar(pd_5mil_dc,volt_5mil_dc,xerr=err_pd_5mil_dc,yerr=err_volt_5mil_dc,fmt='.',label='Al - 0.013 cm (DC)',c='k',alpha=0.9)
axs[0,1].errorbar(pd_10mil_dc[:-3],volt_10mil_dc[:-3],xerr=err_pd_10mil_dc[:-3],yerr=err_volt_10mil_dc[:-3],fmt='.',label='Al - 0.026 cm (DC)',c='C0')
axs[0,0].errorbar(pd_5mil_dc_cu,volt_5mil_dc_cu,xerr=err_pd_5mil_dc_cu,yerr=err_volt_5mil_dc_cu,fmt='.',label='Cu - 0.013 cm (DC)',c='C2')
axs[0,0].errorbar(pd_5mil_dc,volt_5mil_dc,xerr=err_pd_5mil_dc,yerr=err_volt_5mil_dc,fmt='.',label='Al - 0.013 cm (DC)',c='k',alpha=0.9)
axs[1,0].errorbar(pd_5mil_dc_oa,volt_5mil_dc_oa,xerr=err_pd_5mil_dc_oa,yerr=err_volt_5mil_dc_oa,fmt='.',label=r'Cu - SA = 0.4 cm$^2$ (DC)',c='C3')
axs[1,0].errorbar(pd_5mil_dc_cu,volt_5mil_dc_cu,xerr=err_pd_5mil_dc_cu,yerr=err_volt_5mil_dc_cu,fmt='.',label=r'Cu - SA = 1.2 cm$^2$ (DC)',c='C2')

axs[1,1].errorbar(pd_5mil_rf[-12:], volt_5mil_rf[-12:], xerr=err_pd_5mil_rf[-12:], yerr=err_volt_5mil_rf[-12:],fmt='.', label='Al - 0.013 cm (RF)',c='C4')
axs[1,1].errorbar(pd_10mil_rf, volt_10mil_rf, xerr=err_pd_10mil_rf, yerr=err_volt_10mil_rf,fmt='.', label='Al - 0.026 cm (RF)',c='C5')
axs[1,1].errorbar(pd_15mil_rf, volt_15mil_rf, xerr=err_pd_15mil_rf, yerr=err_volt_15mil_rf,fmt='.', label='Al - 0.038 cm (RF)',c='C6')

plt.xscale('log')

axs[0,0].legend(loc='upper left',ncol=1,fontsize=13)
axs[0,1].legend(loc='upper left',ncol=1,fontsize=13)
axs[1,0].legend(loc='upper left',ncol=1,fontsize=13)
axs[1,1].legend(loc='upper left',ncol=1,fontsize=13)

axs[0,0].tick_params(which='major',axis='both',labelsize=13)
axs[1,0].tick_params(which='major',axis='both',labelsize=13)
axs[1,1].tick_params(which='major',axis='both',labelsize=13)
axs[1,0].set_xlabel('Pd [Torr cm]', fontsize=13)
axs[1,1].set_xlabel('Pd [Torr cm]', fontsize=13)
axs[0,0].set_ylabel('Voltage [V]',fontsize=13)
pd_xe_rogers = p_bar_xe_rogers*760*0.5
vt_xe_rogers = volt_kvcm_xe_rogers*1000.*0.5

# %%
p_bar_ar_rogers = np.array([0.9856433,1.5014868,2.0017054,2.48625,2.9864686,3.502312,3.986881,4.487026,5.0028453,5.48739,6.0187855,6.487656,7.0034266,7.503547,8.003644,8.50374,9.003885,9.503958,10.004103])
volt_kvcm_ar_rogers = np.array([6.7240853,7.8822803,9.040678,9.940418,11.098816,12.25701,13.2861805,14.056289,15.085054,15.984794,16.754498,17.39558,18.165485,18.806164,19.317411,19.82866,20.598768,20.980585,21.521313])
pd_ar_rogers = p_bar_ar_rogers*760.*0.5
vt_ar_rogers = volt_kvcm_ar_rogers*1000.*0.5

# %% [markdown]
# ### RF

# %%
# yellow at app vs purple at divided -- 5 mil!
vapp_pp_5_xe = np.array([152.,180.,205.,226.,243.,259.])
vapp_pp_5_xe_std = np.array([1.3,3.,3.5,3.,3.,3.])
vdiv_pp_5_xe = np.array([0.468,0.552,0.618,0.680,0.727,0.778])
vdiv_pp_5_xe_std = np.array([0.011,0.013,0.010,0.008,0.011,0.012])
fact_5_xe_wtstds = vapp_pp_5_xe/vdiv_pp_5_xe*np.sqrt((vdiv_pp_5_xe_std/vdiv_pp_5_xe)**2+(vapp_pp_5_xe_std/vapp_pp_5_xe)**2)
vfactor_5_xe = (vapp_pp_5_xe/vdiv_pp_5_xe).mean()
vfactor_5_xe_std = np.sqrt(sum(fact_5_xe_wtstds**2) + (probe_std*vfactor_5_xe)**2)
print('vfactor_5_xe = %s +/- %s'%(vfactor_5_xe,vfactor_5_xe_std))
# Out:
# vfactor_5_xe = 330.3494435063737 +/- 24.73234773109917

# %%
press_xe_5mil_down = np.array([1.00,1.00,1.00,0.90,0.90,0.90,0.80,0.80,0.80,0.70,0.70,0.70,0.60,0.60,0.60,0.50,0.50,0.50,0.40,0.40,0.40,0.30,0.30,0.30,0.20,0.20,0.20,0.11,0.11,0.11])
volt_xe_5mil_down = np.array([3.02,2.90,2.84,2.78,2.86,2.76,2.52,2.54,2.56,2.36,2.38,2.42,2.20,2.16,2.20,2.18,2.00,2.00,1.90,1.78,1.76,1.64,1.56,1.56,1.42,1.40,1.34,1.34,1.26,1.28])

# %%
pd_5mil_xe_down = press_xe_5mil_down[::3]*pdfactor_5
volt_5mil_xe_down = volt_xe_5mil_down.reshape(int(len(volt_xe_5mil_down)/3),3).mean(axis=1)*vfactor_5_xe/2.
err_pd_5mil_xe_down = np.sqrt((press_xe_5mil_down[::3]*pdfactor_5/10.)**2 + (pdfactor_5*0.01)**2)
err_volt_5mil_xe_down = np.sqrt((vfactor_5_xe_std*volt_xe_5mil_down[::3]/2.)**2 + (vfactor_5_xe*volt_xe_5mil_down.reshape(int(len(volt_xe_5mil_down)/3),3).std(axis=1)/2.)**2)

# %%
press_he_5mil = np.array([10.01,10.01,10.01,9.46,9.46,9.46,8.99,8.99,8.99,8.50,8.50,8.50,8.00,8.00,8.00,7.45,7.45,7.45,6.91,6.91,6.91,6.47,6.47,6.47,6.01,6.01,6.01,5.50,5.50,5.50,4.99,4.99,4.99,4.48,4.48,4.48,3.95,3.95,3.95,3.48,3.48,3.48,2.98,2.98,2.98,2.49,2.49,2.49,1.99,1.99,1.99,1.50,1.50,1.50,1.01,1.01,1.01,0.85,0.85,0.85])
volt_he_5mil = np.array([2.72,2.80,2.80,2.72,2.72,2.76,2.68,2.68,2.64,2.64,2.56,2.56,2.56,2.56,2.56,2.44,2.44,2.40,2.36,2.36,2.32,2.28,2.24,2.24,2.20,2.16,2.16,2.12,2.08,2.08,1.96,2.00,1.96,1.84,1.84,1.88,1.80,1.80,1.72,1.72,1.72,1.72,1.64,1.64,1.56,1.52,1.48,1.48,1.36,1.36,1.36,1.24,1.24,1.20,1.08,1.04,1.04,1.00,0.96,0.96])

# %%
pd_5mil_he = press_he_5mil[::3]*pdfactor_5
volt_5mil_he = volt_he_5mil.reshape(int(len(volt_he_5mil)/3),3).mean(axis=1)*vfactor_5_xe/2.
err_pd_5mil_he = np.sqrt((press_he_5mil[::3]*pdfactor_5/10.)**2 + (pdfactor_5*0.01)**2)
err_volt_5mil_he = np.sqrt((vfactor_5_xe_std*volt_he_5mil[::3]/2.)**2 + (vfactor_5_xe*volt_he_5mil.reshape(int(len(volt_he_5mil)/3),3).std(axis=1)/2.)**2)

# %% [markdown]
# ## Plot breakdown curves

# %%
plt.figure(figsize=(9,7))

l1 = plt.plot(paschen(24.,330.,0.01,np.logspace(-1,3,1000))[0],paschen(24.,330.,0.01,np.logspace(-1,3,1000))[1],label='Petrovic',c='C3',alpha=0.6)
l2 = plt.plot(pd_wittenberg_xe,volt_wittenberg_xe,c='C1',label='Wittenberg',alpha=0.6)

u1 = plt.errorbar(pd_5mil_xe_down, volt_5mil_xe_down, xerr=err_pd_5mil_xe_down, yerr=err_volt_5mil_xe_down,fmt='.', label='0.013 cm (13.56 MHz RF)\n (this work)', c='C0')
u2 = plt.fill_betweenx(vt_xe_5mil_dc_down,pd_xe_5mil_dc_down-err_pd_xe_5mil_dc_down,pd_xe_5mil_dc_down+err_pd_xe_5mil_dc_down,label='0.013 cm (DC) (this work)',color='C0',alpha=0.5,linewidth=0)

j1 = plt.plot(pd_jacques_06,v_jacques_06,'o',c='C3',label=r'Jacques - 0.6 cm (DC)')
j2 = plt.plot(pd_jacques_10,v_jacques_10,'o',c='C4',label=r'Jacques - 1.0 cm (DC)')
j3 = plt.plot(pd_jacques_16,v_jacques_16,'o',c='C5',label=r'Jacques - 1.6 cm (DC)')
j4 = plt.plot(pd_jacques_20,v_jacques_20,'o',c='C6',label=r'Jacques - 2.0 cm (DC)')
b1 = plt.plot(pd_bhattacharya,v_bhattacharya,'^',c='C2',label='Bhattacharya - 2.15 cm (DC)')
b2 = plt.plot(pd_bradford,v_bradford,'s',c='C1',label='Bradford - 3.18 cm (2800 MHz RF)')

d1 = plt.plot(np.array([-10,0]),np.array([-10,0]),c='white',label=' ')

plt.xscale('log')
plt.yscale('log')

plt.xlim(0.8,20)
plt.ylim(50,2900)

plt.tick_params(which='major',axis='both',labelsize=20)
plt.xlabel('Pd [Torr cm]', fontsize=20)
plt.ylabel('Voltage [V]', fontsize=20)

hh = [l1[0],l2[0],j1[0],j2[0],j3[0],j4[0],b1[0],b2[0],u2,u1,d1[0]]
hl = [H.get_label() for H in hh]
plt.legend(hh,hl,loc='upper center', ncol=2,fontsize=14)
#plt.legend(loc='upper center', ncol=2,fontsize=15)
plt.text(10,60,'Xenon',fontsize=24)

plt.tight_layout()
#plt.savefig('plots/xenoncompare_si.pdf',bbox_inches='tight')

# %%
plt.figure(figsize=(9,7))

l1 = plt.plot(paschen(2.8,77.,0.01,np.logspace(-1,3,1000))[0],paschen(2.8,77.,0.01,np.logspace(-1,3,1000))[1],label='Petrovic',c='C3',alpha=0.6)
l2 = plt.plot(pd_wittenberg_he,volt_wittenberg_he,c='C1',label='Wittenberg',alpha=0.6)

u1 = plt.fill_betweenx(vt_he_5mil_dc,pd_he_5mil_dc-err_pd_he_5mil_dc,pd_he_5mil_dc+err_pd_he_5mil_dc,label='0.13 mm (DC) (this work)',color='C3',alpha=0.5,linewidth=0)
u2 = plt.errorbar(pd_5mil_he, volt_5mil_he, xerr=err_pd_5mil_he, yerr=err_volt_5mil_he,fmt='.', label='0.13 mm (RF)\n (this work)', c='C3')

p1 = plt.plot(pd_park_10,volt_park_10,'o',c='C2',label=r'Park - 1.0 mm (RF)')
p2 = plt.plot(pd_park_33,volt_park_33,'o',c='C0',label=r'Park - 3.3 mm (RF)')
p3 = plt.plot(pd_park_97,volt_park_97,'o',c='C4',label=r'Park - 9.7 mm (RF)')
d1 = plt.plot(pd_dezani,volt_dezani,'^',c='C9',label=r'Dezani - 1.0 mm (DC)')
m1 = plt.plot(pd_moravej_he,volt_moravej_he,'s',c='C1',label=r'Moravej - 0.4-2.4 mm (RF)')


d2 = plt.plot(np.array([-10,0]),np.array([-10,0]),c='white',label=' ')

plt.xscale('log')
plt.yscale('log')

plt.xlim(6,120)
plt.ylim(30,3000)

plt.tick_params(which='major',axis='both',labelsize=20)
plt.xlabel('Pd [Torr cm]', fontsize=20)
plt.ylabel('Voltage [V]', fontsize=20)


hh = [l1[0],l2[0],p1[0],p2[0],p3[0],m1[0],d1[0],u1,u2,d2[0],d2[0],d2[0]]
hl = [H.get_label() for H in hh]
plt.legend(hh,hl,loc='upper left', ncol=2,fontsize=14)
plt.text(60,37,'Helium',fontsize=24)

plt.tight_layout()
#plt.savefig('plots/heliumcompare_si.pdf',bbox_inches='tight')

# %%
plt.figure(figsize=(10,6))

plt.fill_betweenx(vt_xe_5mil_dc_down,pd_xe_5mil_dc_down-err_pd_xe_5mil_dc_down,pd_xe_5mil_dc_down+err_pd_xe_5mil_dc_down,label='Xe DC',color='C0',alpha=0.5,linewidth=0)
plt.fill_betweenx(volt_10mil_dc[5:-2],pd_10mil_dc[5:-2]-err_pd_10mil_dc[5:-2],pd_10mil_dc[5:-2]+err_pd_10mil_dc[5:-2],label='Ar DC',color='C4',alpha=0.5,linewidth=0)
plt.fill_betweenx(vt_he_5mil_dc,pd_he_5mil_dc-err_pd_he_5mil_dc,pd_he_5mil_dc+err_pd_he_5mil_dc,label='He DC',color='C3',alpha=0.5,linewidth=0)

plt.errorbar(pd_5mil_xe_down, volt_5mil_xe_down, xerr=err_pd_5mil_xe_down, yerr=err_volt_5mil_xe_down,fmt='.', label='Xe RF', c='C0')
plt.errorbar(pd_5mil_rf[4:], volt_5mil_rf[4:], xerr=err_pd_5mil_rf[4:], yerr=err_volt_5mil_rf[4:],fmt='.', label='Ar RF', c='C4')
plt.errorbar(pd_5mil_he, volt_5mil_he, xerr=err_pd_5mil_he, yerr=err_volt_5mil_he,fmt='.', label='He RF', c='C3')

plt.xlim(0.6,120)
plt.ylim(120,900)

plt.xscale('log')
plt.yscale('log')

plt.legend(loc='upper left',ncol=2, fontsize=13)

plt.tick_params(which='major',axis='both',labelsize=13)
plt.xlabel('Pd [Torr cm]', fontsize=13)
plt.ylabel(r'Voltage [V$_{max}$]',fontsize=13)

plt.tight_layout()
#plt.savefig('plots/RFbreakdowns.pdf',bbox_inches='tight')

# %%
#plt.style.use('default')
plt.figure(figsize=(10,6))

x1 = plt.fill_betweenx(vt_xe_5mil_dc_down,pd_xe_5mil_dc_down-err_pd_xe_5mil_dc_down,pd_xe_5mil_dc_down+err_pd_xe_5mil_dc_down,label='Xe DC (this work)',color='cornflowerblue',alpha=0.5,linewidth=0)
x2 = plt.errorbar(pd_5mil_xe_down, volt_5mil_xe_down, xerr=err_pd_5mil_xe_down, yerr=err_volt_5mil_xe_down,fmt='.', label='Xe RF (this work)', c='cornflowerblue')
x3 = plt.plot(pd_xe_rogers,vt_xe_rogers,'s', c='cornflowerblue',label='Rogers - Xe DC (5 mm)')

a1 = plt.fill_betweenx(volt_10mil_dc[5:-2],pd_10mil_dc[5:-2]-err_pd_10mil_dc[5:-2],pd_10mil_dc[5:-2]+err_pd_10mil_dc[5:-2],label='Ar DC (this work)',color='C4',alpha=0.5,linewidth=0)
a2 = plt.errorbar(pd_5mil_rf[4:], volt_5mil_rf[4:], xerr=err_pd_5mil_rf[4:], yerr=err_volt_5mil_rf[4:],fmt='.', label='Ar RF (this work)', c='C4')
a3 = plt.plot(pd_ar_rogers,vt_ar_rogers,'^',c='C4',label='Rogers - Ar DC (5 mm)')

plt.xscale('log')
plt.yscale('log')

plt.ylim(100,40000)
plt.xlim(0.6,6000)

hh = [x3[0],x1,x2,a3[0],a1,a2]
hl = [H.get_label() for H in hh]

plt.tick_params(which='major',axis='both',labelsize=15)
plt.legend(hh,hl,loc='upper left',ncol=2,fontsize=15)

plt.xlabel('Pd [Torr cm]',fontsize=15)
plt.ylabel(r'Voltage [V]',fontsize=15)

plt.tight_layout()
#plt.savefig('plots/rogerscompare_bw.pdf',bbox_inches='tight')
